# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
prices = pd.read_csv("stock.csv", parse_dates=["Date"])

# %%
prices
# Out:
#            Date  Open Price  High Price   Low Price  Close Price  \
# 0    2014-05-27   87.982857   89.408569   87.947144    89.375717
# 1    2014-05-28   89.431427   89.975716   89.111427    89.144287
# 2    2014-05-29   89.692856   90.981430   89.681427    90.768570
# 3    2014-05-30   91.139999   92.024284   89.842857    90.428574
# 4    2014-06-02   90.565712   90.690002   88.928574    89.807144
# ...         ...         ...         ...         ...          ...
# 1505 2020-05-18  313.170013  316.500000  310.320007   314.959991
# 1506 2020-05-19  315.029999  318.519989  313.010010   313.140015
# 1507 2020-05-20  316.679993  319.519989  316.519989   319.230011
# 1508 2020-05-21  318.660004  320.890015  315.869995   316.850006
# 1509 2020-05-22  315.769989  319.230011  315.350006   318.890015
#
#       Adj Close Price     Volume
# 0           80.948952   87216500
# 1           80.739334   78870400
# 2           82.210480   94118500
# 3           81.902557  141005200
# ...

# %%
stock = pd.DataFrame()

# %%
stock["Date"] = prices["Date"]
stock["Apple"] = prices["Adj Close Price"]

# %%
stock.head()
# Out:
#         Date      Apple
# 0 2014-05-27  80.948952
# 1 2014-05-28  80.739334
# 2 2014-05-29  82.210480
# 3 2014-05-30  81.902557
# 4 2014-06-02  81.339699

# %%
stock["Apple"].head(30).mean(), stock["Apple"].iloc[1:31].mean()
# Out:
# (83.3759654, 83.55753913333332)

# %%
stock["SMA30"] = stock["Apple"].rolling(30).mean()

# %%
pd.options.display.max_rows = None

# %%
stock
# Out:
#            Date       Apple       SMA30
# 0    2014-05-27   80.948952         NaN
# 1    2014-05-28   80.739334         NaN
# 2    2014-05-29   82.210480         NaN
# 3    2014-05-30   81.902557         NaN
# 4    2014-06-02   81.339699         NaN
# 5    2014-06-03   82.489952         NaN
# 6    2014-06-04   83.431915         NaN
# 7    2014-06-05   83.759270         NaN
# 8    2014-06-06   83.528938         NaN
# 9    2014-06-09   84.865509         NaN
# 10   2014-06-10   85.363655         NaN
# 11   2014-06-11   85.010437         NaN
# 12   2014-06-12   83.588470         NaN
# 13   2014-06-13   82.673691         NaN
# 14   2014-06-16   83.506935         NaN
# 15   2014-06-17   83.398270         NaN
# 16   2014-06-18   83.488853         NaN
# 17   2014-06-19   83.199013         NaN
# 18   2014-06-20   82.338593         NaN
# 19   2014-06-23   82.266121         NaN
# 20   2014-06-24   81.767960         NaN
# 21   2014-06-25   81.840439         NaN
# ...

# %%
stock["SMA100"] = stock["Apple"].rolling(100).mean()

# %%
stock
# Out:
#            Date       Apple       SMA30      SMA100
# 0    2014-05-27   80.948952         NaN         NaN
# 1    2014-05-28   80.739334         NaN         NaN
# 2    2014-05-29   82.210480         NaN         NaN
# 3    2014-05-30   81.902557         NaN         NaN
# 4    2014-06-02   81.339699         NaN         NaN
# 5    2014-06-03   82.489952         NaN         NaN
# 6    2014-06-04   83.431915         NaN         NaN
# 7    2014-06-05   83.759270         NaN         NaN
# 8    2014-06-06   83.528938         NaN         NaN
# 9    2014-06-09   84.865509         NaN         NaN
# 10   2014-06-10   85.363655         NaN         NaN
# 11   2014-06-11   85.010437         NaN         NaN
# 12   2014-06-12   83.588470         NaN         NaN
# 13   2014-06-13   82.673691         NaN         NaN
# 14   2014-06-16   83.506935         NaN         NaN
# 15   2014-06-17   83.398270         NaN         NaN
# 16   2014-06-18   83.488853         NaN         NaN
# ...

# %%
for i, row in stock.iterrows():
    print(row["SMA30"])
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 83.3759654
# 83.55753913333334
# 83.73553443333334
# 83.86992543333334
# 84.0517146
# 84.21815086666668
# 84.32994236666667
# 84.359313
# 84.41822716666667
# 84.47002593333333
# 84.5008207
# 84.5895816
# 84.68528473333335
# 84.84770923333332
# 85.0813836
# 85.26796173333334
# 85.4512175
# 85.5544689
# 85.683382
# 85.82467276666668
# 85.95419063333334
# 86.09548243333333
# 86.23405436666667
# 86.36421283333333
# 86.49969103333333
# 86.60588126666667
# 86.7327937
# 86.86880063333334
# 87.0027682
# 87.11396713333333
# 87.28545000000001
# 87.45694023333334
# 87.63929929999999
# 87.8386765
# 88.00759509999999
# 88.19090603333333
# 88.42814279999999
# 88.72004293333333
# 88.97907260000001
# 89.2771688
# 89.41943106666668
# 89.4622424
# 89.5356753
# 89.5712776
# 89.55489653333333
# 89.64916253333332
# 89.76341906666667
# ...

# %%
def buy_sell(df):
    buy_price_price = []
    sell_price_price = []
    holding = [] # 1 for hold, 0 for not hold
    actions = [] # 1 for buy, -1 for sell, 0 for wait
    sig = 0
    for i,row in df.iterrows():
        if row["SMA30"] > row["SMA100"]: # buy
            if sig != 1:
                buy_price_price.append(row["Apple"])
                sell_price_price.append(np.nan)
                sig = 1
                actions.append(1)
                holding.append(1)
            else:
                buy_price_price.append(np.nan)
                sell_price_price.append(np.nan)
                actions.append(0)
                holding.append(1)
        elif row["SMA30"] < row["SMA100"]: # sell
            if sig != -1:
                buy_price_price.append(np.nan)
                sell_price_price.append(row["Apple"])
                sig = -1
                actions.append(-1)
                holding.append(0)
            else:
                buy_price_price.append(np.nan)
                sell_price_price.append(np.nan)
                actions.append(0)
                holding.append(0)
        else:
            holding.append(0)
            buy_price_price.append(np.nan)
            sell_price_price.append(np.nan)
            actions.append(0)
            
    return buy_price_price, sell_price_price, holding, actions

# %%
buysell = buy_sell(stock)

# %%
stock["Buy Price"], stock["Sell Price"], stock["Hold"], stock["Actions"] = buysell

# %%
stock
# Out:
#            Date       Apple       SMA30      SMA100   Buy Price  Sell Price  \
# 0    2014-05-27   80.948952         NaN         NaN         NaN         NaN
# 1    2014-05-28   80.739334         NaN         NaN         NaN         NaN
# 2    2014-05-29   82.210480         NaN         NaN         NaN         NaN
# 3    2014-05-30   81.902557         NaN         NaN         NaN         NaN
# 4    2014-06-02   81.339699         NaN         NaN         NaN         NaN
# 5    2014-06-03   82.489952         NaN         NaN         NaN         NaN
# 6    2014-06-04   83.431915         NaN         NaN         NaN         NaN
# 7    2014-06-05   83.759270         NaN         NaN         NaN         NaN
# 8    2014-06-06   83.528938         NaN         NaN         NaN         NaN
# 9    2014-06-09   84.865509         NaN         NaN         NaN         NaN
# 10   2014-06-10   85.363655         NaN         NaN         NaN         NaN
# ...

# %%
113.615921 - 88.782898
# Out:
# 24.833022999999997

# %%
97.948441 - 110.918350
# Out:
# -12.969909000000001

# %%
plt.figure(figsize=(16,5))
plt.style.use("dark_background")

plt.plot(stock["Date"], stock["Apple"], label = "Apple", alpha = 0.35)
plt.plot(stock["Date"], stock["SMA30"], label = "SMA30", alpha = 0.35)
plt.plot(stock["Date"], stock["SMA100"], label = "SMA100", alpha = 0.35)

plt.scatter(stock["Date"], stock["Buy Price"], color = "green", s = 100, marker = "^")
plt.scatter(stock["Date"], stock["Sell Price"], color = "red", s = 100, marker = "v")

plt.title("Apple Historical Adj Close Price",weight = "bold")
plt.xlabel("From May, 2014 to 22 May, 2020",weight = "bold")
plt.ylabel("Adj Close Price",weight = "bold")

plt.show()

# %%
stock["Buy Price"].sum()
# Out:
# 1263.89878

# %%
stock["Sell Price"].sum()
# Out:
# 1048.588593
